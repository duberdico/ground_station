# %%
from sklearn.datasets import load_iris
import seaborn as sns
import random
import pandas as pd
import numpy as np
sns.set(style="ticks", color_codes=True)

# %%
n = 1000
sigma = 0.3
p_missing = 0.1

# %%
iris = sns.load_dataset("iris")
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
temp = pd.DataFrame(data=None, columns=iris.columns)
for i in range(n):
    j = random.randrange(len(iris))
    cur = iris.iloc[j].copy()
    cur['sepal_length'] = random.gauss(cur['sepal_length'],sigma)
    cur['sepal_width'] = random.gauss(cur['sepal_width'],sigma)
    cur['petal_length'] = random.gauss(cur['petal_length'],sigma)
    temp = temp.append(cur)
iris = iris.append(temp,ignore_index=True)

# %%
 g = sns.pairplot(iris, hue="species", markers=["o", "s", "D"])
# Out:
# C:\Users\ricardo.antunes\AppData\Local\Continuum\anaconda3\envs\TEPUK\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
I = iris.copy()
m = random.sample(range(len(iris)),int(p_missing*len(iris)))
n = random.choice(range(len(iris.columns)))
I.loc[m,iris.columns[n]] = np.NaN

# %%
# Out:
#       sepal_length  sepal_width  petal_length  petal_width     species
# 0              NaN     3.500000      1.400000          0.2      setosa
# 1              NaN     3.000000      1.400000          0.2      setosa
# 2              NaN     3.200000      1.300000          0.2      setosa
# 3         4.600000     3.100000      1.500000          0.2      setosa
# 4         5.000000     3.600000      1.400000          0.2      setosa
# 5         5.400000     3.900000      1.700000          0.4      setosa
# 6         4.600000     3.400000      1.400000          0.3      setosa
# 7         5.000000     3.400000      1.500000          0.2      setosa
# 8              NaN     2.900000      1.400000          0.2      setosa
# 9         4.900000     3.100000      1.500000          0.1      setosa
# 10        5.400000     3.700000      1.500000          0.2      setosa
# 11        4.800000     3.400000      1.600000          0.2      setosa
# 12        4.800000     3.000000      1.400000          0.1      setosa
# 13        4.300000     3.000000      1.100000          0.1      setosa
# 14        5.800000     4.000000      1.200000          0.2      setosa
# 15        5.700000     4.400000      1.500000          0.4      setosa
# 16        5.400000     3.900000      1.300000          0.4      setosa
# 17        5.100000     3.500000      1.400000          0.3      setosa
# 18             NaN     3.800000      1.700000          0.3      setosa
# 19        5.100000     3.800000      1.500000          0.3      setosa
# 20        5.400000     3.400000      1.700000          0.2      setosa
# 21        5.100000     3.700000      1.500000          0.4      setosa
# 22        4.600000     3.600000      1.000000          0.2      setosa
# 23        5.100000     3.300000      1.700000          0.5      setosa
# 24        4.800000     3.400000      1.900000          0.2      setosa
# 25        5.000000     3.000000      1.600000          0.2      setosa
# 26        5.000000     3.400000      1.600000          0.4      setosa
# 27        5.200000     3.500000      1.500000          0.2      setosa
# 28        5.200000     3.400000      1.400000          0.2      setosa
# 29        4.700000     3.200000      1.600000          0.2      setosa
# ...            ...          ...           ...          ...         ...
# 1120      5.978653     2.210174      3.705605          1.1  versicolor
# 1121      4.805635     2.958944      1.208261          0.2      setosa
# 1122      7.523882     2.609688      7.125976          2.3   virginica
# 1123      5.876914     4.153506      1.394792          0.2      setosa
# 1124      6.566632     3.154096      4.900263          1.6  versicolor
# 1125      6.347211     3.836153      4.968331          1.4  versicolor
# 1126      6.033733     2.633328      4.309867          1.5  versicolor
# 1127      6.058145     3.046340      4.631971          1.3  versicolor
# 1128      5.621950     3.153972      4.907978          1.5  versicolor
# 1129      6.236441     3.034504      5.224714          2.0   virginica
# 1130      7.205584     2.696261      4.587333          1.5  versicolor
# 1131           NaN     3.250310      1.726863          0.2      setosa
# 1132      5.218004     4.566475      1.600972          0.4      setosa
# 1133           NaN     3.177352      5.167430          2.4   virginica
# 1134      6.519486     2.906060      5.693714          2.4   virginica
# 1135      4.921294     3.244580      1.692115          0.2      setosa
# 1136      5.773841     2.971855      5.417380          1.9   virginica
# 1137      8.013839     3.068548      6.075568          2.3   virginica
# 1138      6.195416     3.055138      4.342109          1.4  versicolor
# 1139      5.103763     3.342412      1.173095          0.4      setosa
# 1140      5.558633     2.650348      4.794735          1.5  versicolor
# 1141      6.221673     2.984682      5.775270          2.5   virginica
# 1142      4.958574     3.523974      1.613447          0.2      setosa
# 1143      5.606602     2.492089      4.018435          1.2  versicolor
# 1144      7.016932     3.191098      6.450523          2.5   virginica
# 1145      7.141729     2.847929      5.633086          2.1   virginica
# 1146      5.059389     3.212072      1.565708          0.2      setosa
# 1147      7.573263     2.882638      6.278557          2.3   virginica
# 1148      5.449147     3.699431      1.086962          0.2      setosa
# 1149      4.781842     3.791322      1.337039          0.2      setosa
#
# [1150 rows x 5 columns]

# %%
~
